# %% [markdown]
# # DSX R ML Installation Steps (Decison Tree)

# %% [markdown]
# ## Installing Brunel

# %%
try(system("pip install brunel --upgrade --user", intern = TRUE, ignore.stderr = TRUE))
# Out:
#  [1] "Collecting brunel"
#  [2] "  Downloading brunel-2.2.zip (2.1MB)"
#  [3] "Collecting pandas (from brunel)"
#  [4] "  Downloading pandas-0.19.2-cp27-cp27m-manylinux1_x86_64.whl (17.2MB)"
#  [5] "Collecting jinja2 (from brunel)"
#  [6] "  Downloading Jinja2-2.9.5-py2.py3-none-any.whl (340kB)"
#  [7] "Collecting ipython (from brunel)"
#  [8] "  Downloading ipython-5.3.0-py2-none-any.whl (750kB)"
#  [9] "Requirement already up-to-date: jupyter-pip in /usr/local/src/bluemix_jupyter_bundle.v36/notebook/lib/python2.7/site-packages (from brunel)"
# [10] "Collecting JPype1 (from brunel)"
# [11] "  Downloading JPype1-0.6.2.tar.gz (147kB)"
# [12] "Collecting pytz>=2011k (from pandas->brunel)"
# [13] "  Downloading pytz-2016.10-py2.py3-none-any.whl (483kB)"
# [14] "Collecting numpy>=1.7.0 (from pandas->brunel)"
# [15] "  Downloading numpy-1.12.0-cp27-cp27m-manylinux1_x86_64.whl (16.5MB)"
# [16] "Collecting python-dateutil (from pandas->brunel)"
# [17] "  Downloading python_dateutil-2.6.0-py2.py3-none-any.whl (194kB)"
# [18] "Collecting MarkupSafe>=0.23 (from jinja2->brunel)"
# [19] "  Downloading MarkupSafe-1.0.tar.gz"
# [20] "Collecting pygments (from ipython->brunel)"
# [21] "  Downloading Pygments-2.2.0-py2.py3-none-any.whl (841kB)"
# [22] "Collecting setuptools>=18.5 (from ipython->brunel)"
# [23] "  Downloading setuptools-34.3.2-py2.py3-none-any.whl (389kB)"
# [24] "Collecting prompt-toolkit<2.0.0,>=1.0.4 (from ipython->brunel)"
# [25] "  Downloading prompt_toolkit-1.0.13-py2-none-any.whl (247kB)"
# [26] "Requirement already up-to-date: backports.shutil-get-terminal-size; python_version == \"2.7\" in /usr/local/src/bluemix_jupyter_bundle.v36/notebook/lib/python2.7/site-packages (from ipython->brunel)"
# [27] "Collecting pickleshare (from ipython->brunel)"
# [28] "  Downloading pickleshare-0.7.4-py2.py3-none-any.whl"
# [29] "Collecting traitlets>=4.2 (from ipython->brunel)"
# [30] "  Downloading traitlets-4.3.2-py2.py3-none-any.whl (74kB)"
# [31] "Collecting pexpect; sys_platform != \"win32\" (from ipython->brunel)"
# [32] "  Downloading pexpect-4.2.1-py2.py3-none-any.whl (55kB)"
# [33] "Collecting pathlib2; python_version == \"2.7\" or python_version == \"3.3\" (from ipython->brunel)"
# [34] "  Downloading pathlib2-2.2.1-py2.py3-none-any.whl"
# [35] "Requirement already up-to-date: simplegeneric>0.8 in /usr/local/src/bluemix_jupyter_bundle.v36/notebook/lib/python2.7/site-packages (from ipython->brunel)"
# [36] "Collecting decorator (from ipython->brunel)"
# [37] "  Downloading decorator-4.0.11-py2.py3-none-any.whl"
# [38] "Requirement already up-to-date: six>=1.5 in /usr/local/src/bluemix_jupyter_bundle.v36/notebook/lib/python2.7/site-packages (from python-dateutil->pandas->brunel)"
# [39] "Collecting appdirs>=1.4.0 (from setuptools>=18.5->ipython->brunel)"
# [40] "  Downloading appdirs-1.4.3-py2.py3-none-any.whl"
# [41] "Requirement already up-to-date: packaging>=16.8 in /usr/local/src/bluemix_jupyter_bundle.v36/notebook/lib/python2.7/site-packages (from setuptools>=18.5->ipython->brunel)"
# [42] "Collecting wcwidth (from prompt-toolkit<2.0.0,>=1.0.4->ipython->brunel)"
# [43] "  Downloading wcwidth-0.1.7-py2.py3-none-any.whl"
# [44] "Collecting enum34; python_version == \"2.7\" (from traitlets>=4.2->ipython->brunel)"
# [45] "  Downloading enum34-1.1.6-py2-none-any.whl"
# [46] "Collecting ipython-genutils (from traitlets>=4.2->ipython->brunel)"
# [47] "  Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl"
# [48] "Collecting ptyprocess>=0.5 (from pexpect; sys_platform != \"win32\"->ipython->brunel)"
# [49] "  Downloading ptyprocess-0.5.1-py2.py3-none-any.whl"
# [50] "Collecting scandir; python_version < \"3.5\" (from pathlib2; python_version == \"2.7\" or python_version == \"3.3\"->ipython->brunel)"
# [51] "  Downloading scandir-1.5.tar.gz"
# [52] "Collecting pyparsing (from packaging>=16.8->setuptools>=18.5->ipython->brunel)"
# [53] "  Downloading pyparsing-2.2.0-py2.py3-none-any.whl (56kB)"
# [54] "Building wheels for collected packages: brunel, JPype1, MarkupSafe, scandir"
# [55] "  Running setup.py bdist_wheel for brunel: started"
# [56] "  Running setup.py bdist_wheel for brunel: finished with status 'done'"
# [57] "  Stored in directory: /gpfs/fs01/user/s053-4b42d32a384819-1819ffdc8efc/.cache/pip/wheels/88/59/ce/4002c060573c3a0765a50fd39d42ac1c937ebeb2284c2ed2ca"
# [58] "  Running setup.py bdist_wheel for JPype1: started"
# [59] "  Running setup.py bdist_wheel for JPype1: finished with status 'done'"
# [60] "  Stored in directory: /gpfs/fs01/user/s053-4b42d32a384819-1819ffdc8efc/.cache/pip/wheels/8e/f3/e6/a1250b8e8d2bd105f4dd21b1dc801dbcf5d815592443bfe741"
# [61] "  Running setup.py bdist_wheel for MarkupSafe: started"
# [62] "  Running setup.py bdist_wheel for MarkupSafe: finished with status 'done'"
# [63] "  Stored in directory: /gpfs/fs01/user/s053-4b42d32a384819-1819ffdc8efc/.cache/pip/wheels/88/a7/30/e39a54a87bcbe25308fa3ca64e8ddc75d9b3e5afa21ee32d57"
# [64] "  Running setup.py bdist_wheel for scandir: started"
# [65] "  Running setup.py bdist_wheel for scandir: finished with status 'done'"
# [66] "  Stored in directory: /gpfs/fs01/user/s053-4b42d32a384819-1819ffdc8efc/.cache/pip/wheels/47/af/a2/eb591a17e9709a17d8b53696f6ad89914a05eaf9c091f36e18"
# [67] "Successfully built brunel JPype1 MarkupSafe scandir"
# [68] "Installing collected packages: pytz, numpy, python-dateutil, pandas, MarkupSafe, jinja2, pygments, appdirs, setuptools, wcwidth, prompt-toolkit, scandir, pathlib2, pickleshare, enum34, ipython-genutils, decorator, traitlets, ptyprocess, pexpect, ipython, JPype1, brunel, pyparsing"
# [69] "Successfully installed JPype1-0.6.2 MarkupSafe-1.0 appdirs-1.4.3 brunel-2.2 decorator-4.0.11 enum34-1.1.6 ipython-5.3.0 ipython-genutils-0.2.0 jinja2-2.9.5 numpy-1.12.0 pandas-0.19.2 pathlib2-2.2.1 pexpect-4.2.1 pickleshare-0.7.4 prompt-toolkit-1.0.13 ptyprocess-0.5.1 pygments-2.2.0 pyparsing-2.2.0 python-dateutil-2.6.0 pytz-2016.10 scandir-1.5 setuptools-34.3.2 traitlets-4.3.2 wcwidth-0.1.7"

# %% [markdown]
# ## Installing supporting R packages

# %% [markdown]
# ### Installing R packages for Brunel

# %%
install.packages("devtools")
# Out:
# Installing package into ‘/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/R/libs’
# (as ‘lib’ is unspecified)

# %%
devtools::install_github("Brunel-Visualization/Brunel", subdir="R", ref="master2.1", force=TRUE)
# Out:
# Downloading GitHub repo Brunel-Visualization/Brunel@master2.1
# from URL https://api.github.com/repos/Brunel-Visualization/Brunel/zipball/master2.1
# Installing brunel
# Installing jsonlite
# '/usr/local/src/bluemix_jupyter_bundle/R/lib64/R/bin/R' --no-site-file  \
#   --no-environ --no-save --no-restore --quiet CMD INSTALL  \
#   '/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/notebook/tmp/Rtmp8eOZ8e/devtools2a4a713b88e5/jsonlite'  \
#   --library='/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/R/libs'  \
#   --install-tests
#
# '/usr/local/src/bluemix_jupyter_bundle/R/lib64/R/bin/R' --no-site-file  \
#   --no-environ --no-save --no-restore --quiet CMD INSTALL  \
#   '/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/notebook/tmp/Rtmp8eOZ8e/devtools2a4a367e676f/Brunel-Visualization-Brunel-e22ad23/R'  \
#   --library='/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/R/libs'  \
#   --install-tests

# %% [markdown]
# ### Installing R packages for machine learning

# %%
install.packages("arules")
# Out:
# Installing package into ‘/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/R/libs’
# (as ‘lib’ is unspecified)

# %%
install.packages("C50")
# Out:
# Installing package into ‘/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/R/libs’
# (as ‘lib’ is unspecified)
# also installing the dependencies ‘Formula’, ‘partykit’

# %%
# a package supporting model transformations for visualization
devtools::install_github("ibmdataworks/datafirst", subdir="datascientist/machinelearning/sigmoml", force=TRUE)
# Out:
# Downloading GitHub repo ibmdataworks/datafirst@master
# from URL https://api.github.com/repos/ibmdataworks/datafirst/zipball/master
# Installing sigmoml
# Installing plyr
# Installing Rcpp
# '/usr/local/src/bluemix_jupyter_bundle/R/lib64/R/bin/R' --no-site-file  \
#   --no-environ --no-save --no-restore --quiet CMD INSTALL  \
#   '/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/notebook/tmp/Rtmp8eOZ8e/devtools2a4a20e1c1ff/Rcpp'  \
#   --library='/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/R/libs'  \
#   --install-tests
#
# '/usr/local/src/bluemix_jupyter_bundle/R/lib64/R/bin/R' --no-site-file  \
#   --no-environ --no-save --no-restore --quiet CMD INSTALL  \
#   '/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/notebook/tmp/Rtmp8eOZ8e/devtools2a4a2bd5eefa/plyr'  \
#   --library='/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/R/libs'  \
#   --install-tests
#
# '/usr/local/src/bluemix_jupyter_bundle/R/lib64/R/bin/R' --no-site-file  \
#   --no-environ --no-save --no-restore --quiet CMD INSTALL  \
#   '/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/notebook/tmp/Rtmp8eOZ8e/devtools2a4a78e37cf6/ibmdataworks-datafirst-1ef1331/datascientist/machinelearning/sigmoml'  \
#   --library='/gpfs/global_fs01/sym_shared/YPProdSpark/user/s053-4b42d32a384819-1819ffdc8efc/R/libs'  \
#   --install-tests
